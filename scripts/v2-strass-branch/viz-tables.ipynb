# %% [markdown]
# # Multimodal ML Performance Tables

# %%
"""
Multimodal ML Performance Tables with great_tables
=================================================
Professional table outputs for benchmark reporting

Author: Senior ML Engineer
Dependencies: great_tables, pandas, numpy
Estimated Runtime: ~5-10 seconds
"""

import pandas as pd
import numpy as np
#from great_tables import GT, html, style, loc
from great_tables import GT, html, style, loc
import matplotlib.pyplot as plt
import io
import base64

class MultimodalTableGenerator:
    """
    Single Responsibility: Generate professional tables for ML benchmarks
    Open/Closed: Extensible for new table formats
    """
    
    def __init__(self):
        """Initialize table generator with styling configurations."""
        self.color_palette = {
            'high_performance': '#2E8B57',      # Sea Green
            'medium_performance': '#FFD700',    # Gold  
            'low_performance': '#DC143C',       # Crimson
            'header_bg': '#2C3E50',            # Dark Blue Grey
            'alt_row': '#F8F9FA'               # Light Grey
        }
    
    def generate_comprehensive_benchmark_data(self) -> dict:
        """Generate comprehensive benchmark data for tables."""
        
        # Main model comparison table
        model_comparison = pd.DataFrame({
            'Model': ['AudioViT-L', 'VideoMAE-B', 'BERT-Large', 'CLIP-ViT-B', 'MM-Fusion-XL'],
            'Accuracy': [0.847, 0.823, 0.789, 0.891, 0.924],
            'F1_Score': [0.834, 0.798, 0.765, 0.856, 0.912],
            'fMRI_R': [0.720, 0.680, 0.590, 0.810, 0.870],
            'Training_Hours': [12.3, 8.7, 4.2, 15.6, 28.9],
            'Inference_ms': [45.2, 23.1, 8.9, 67.3, 89.4],
            'Memory_GB': [8.2, 6.1, 3.4, 11.7, 16.8],
            'Code_Available': ['✓', '✓', '✓', '✓', '✓'],
            'Pretrained': ['✓', '✓', '✓', '✓', '✗']
        })
        
        # Modality-specific performance
        modality_performance = pd.DataFrame({
            'Modality': ['Audio Only', 'Video Only', 'Text Only', 'Audio+Video', 'Audio+Text', 'Video+Text', 'All Modalities'],
            'Accuracy': [0.723, 0.756, 0.812, 0.834, 0.867, 0.845, 0.924],
            'Precision': [0.718, 0.743, 0.798, 0.823, 0.856, 0.834, 0.912],
            'Recall': [0.729, 0.769, 0.826, 0.845, 0.878, 0.856, 0.934],
            'F1_Score': [0.723, 0.756, 0.812, 0.834, 0.867, 0.845, 0.923],
            'Improvement_vs_Best_Single': [0.000, 0.033, 0.089, 0.122, 0.155, 0.133, 0.212]
        })
        
        # Audio-specific metrics
        audio_metrics = pd.DataFrame({
            'Audio_Model': ['Wav2Vec2', 'Whisper-Large', 'AudioMAE', 'HuBERT', 'Custom-Audio'],
            'WER': [0.087, 0.045, 0.123, 0.098, 0.063],
            'BLEU': [0.756, 0.834, 0.689, 0.723, 0.798],
            'Semantic_Score': [0.823, 0.867, 0.745, 0.789, 0.856],
            'Downstream_Boost': [0.123, 0.187, 0.098, 0.145, 0.167]
        })
        
        # Video quality metrics
        video_metrics = pd.DataFrame({
            'Video_Model': ['VideoMAE', 'ViViT', 'TimeSformer', 'X-CLIP', 'Custom-Video'],
            'Resolution': ['224×224', '224×224', '224×224', '224×224', '384×384'],
            'FPS': [16, 8, 8, 12, 24],
            'Feature_R2': [0.812, 0.789, 0.743, 0.823, 0.856],
            'MSE': [0.067, 0.098, 0.089, 0.054, 0.043],
            'Temporal_Align': [0.923, 0.878, 0.845, 0.889, 0.934]
        })
        
        # External benchmark alignment
        benchmark_scores = pd.DataFrame({
            'Benchmark': ['Algonauts 2023', 'BOLD5000', 'NSD', 'GOD', 'DecNef', 'fMRI-Recon'],
            'Our_Score': [0.823, 0.767, 0.845, 0.789, 0.734, 0.812],
            'SOTA_Score': [0.856, 0.798, 0.867, 0.823, 0.756, 0.834],
            'Rank': [3, 4, 2, 3, 5, 2],
            'Gap_to_SOTA': [-0.033, -0.031, -0.022, -0.034, -0.022, -0.022],
            'Participants': [847, 156, 234, 89, 67, 123]
        })
        
        return {
            'model_comparison': model_comparison,
            'modality_performance': modality_performance,
            'audio_metrics': audio_metrics,
            'video_metrics': video_metrics,
            'benchmark_scores': benchmark_scores
        }

# %% [markdown]
# # Access specific DataFrames
#
# model_comparison = benchmark_data['model_comparison']
#
# modality_performance = benchmark_data['modality_performance']
#
# audio_metrics = benchmark_data['audio_metrics']
#
# video_metrics = benchmark_data['video_metrics']
#
# benchmark_scores = benchmark_data['benchmark_scores']

# %%
# 1. Instantiate the table generator
table_generator = MultimodalTableGenerator()

# 2. Generate the benchmark data (returns a dictionary of DataFrames)
benchmark_data = table_generator.generate_comprehensive_benchmark_data()

# 3. Access specific DataFrames
model_comparison = benchmark_data['model_comparison']
modality_performance = benchmark_data['modality_performance']
audio_metrics = benchmark_data['audio_metrics']
video_metrics = benchmark_data['video_metrics']
benchmark_scores = benchmark_data['benchmark_scores']

# 4. (Optional) Display one
print(model_comparison)
# Out:
#           Model  Accuracy  F1_Score  fMRI_R  Training_Hours  Inference_ms  \
# 0    AudioViT-L     0.847     0.834    0.72            12.3          45.2
# 1    VideoMAE-B     0.823     0.798    0.68             8.7          23.1
# 2    BERT-Large     0.789     0.765    0.59             4.2           8.9
# 3    CLIP-ViT-B     0.891     0.856    0.81            15.6          67.3
# 4  MM-Fusion-XL     0.924     0.912    0.87            28.9          89.4
#
#    Memory_GB Code_Available Pretrained
# 0        8.2              ✓          ✓
# 1        6.1              ✓          ✓
# 2        3.4              ✓          ✓
# 3       11.7              ✓          ✓
# 4       16.8              ✓          ✗

# %%
"""
Multimodal ML Performance Tables with great_tables
=================================================
Professional table outputs for benchmark reporting

Author: Senior ML Engineer
Dependencies: great_tables, pandas, numpy, matplotlib
Estimated Runtime: ~10-15 seconds

Time Estimates:
- Neurodivergent/Burned Out: 45-60 minutes to understand and modify
- Average Person (Regulated): 15-25 minutes to understand and modify
"""

import pandas as pd
import numpy as np
from great_tables import GT, html, style, loc
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Dict, Tuple
import warnings
warnings.filterwarnings('ignore')

class MultimodalBenchmarkVisualizer:
    """
    Single Responsibility: Generate professional benchmark visualization tables
    Open/Closed: Extensible for new metrics and table types
    Liskov Substitution: All table methods return GT objects
    Interface Segregation: Specific methods for each benchmark type
    Dependency Inversion: Depends on abstractions (pandas, great_tables)
    """
    
    def __init__(self):
        """Initialize with professional color palette and styling."""
        self.colors = {
            'excellent': '#2E8B57',    # Sea Green (>90%)
            'good': '#32CD32',         # Lime Green (80-90%)
            'average': '#FFD700',      # Gold (70-80%)
            'poor': '#FF6347',         # Tomato (60-70%)
            'very_poor': '#DC143C',    # Crimson (<60%)
            'header_bg': '#2C3E50',    # Dark Blue Grey
            'accent': '#3498DB',       # Dodger Blue
            'neutral': '#ECF0F1'       # Light Grey
        }
    
    def generate_benchmark_data(self) -> Dict[str, pd.DataFrame]:
        """Generate comprehensive benchmark datasets."""
        
        # Primary Model Comparison
        model_comparison = pd.DataFrame({
            'Model': ['AudioViT-L', 'VideoMAE-B', 'BERT-Large', 'CLIP-ViT-B', 'MM-Fusion-XL', 'GPT-4V', 'LLaVA-1.5'],
            'fMRI_Accuracy': [0.847, 0.823, 0.789, 0.891, 0.924, 0.912, 0.889],
            'Classification_Acc': [0.834, 0.798, 0.765, 0.856, 0.912, 0.898, 0.873],
            'Regression_R2': [0.720, 0.680, 0.590, 0.810, 0.870, 0.845, 0.823],
            'Training_Hours': [12.3, 8.7, 4.2, 15.6, 28.9, 45.2, 32.1],
            'Inference_ms': [45.2, 23.1, 8.9, 67.3, 89.4, 156.7, 123.4],
            'Memory_GB': [8.2, 6.1, 3.4, 11.7, 16.8, 24.3, 19.2],
            'Code_Available': ['✓', '✓', '✓', '✓', '✓', '✗', '✓'],
            'Pretrained': ['✓', '✓', '✓', '✓', '✗', '✓', '✓'],
            'Ease_of_Use': [8.5, 9.2, 9.8, 7.8, 6.5, 5.2, 7.1]
        })
        
        # Modality Ablation Study
        ablation_study = pd.DataFrame({
            'Modality_Combination': ['Audio Only', 'Video Only', 'Text Only', 'Audio+Video', 'Audio+Text', 'Video+Text', 'All Modalities'],
            'Accuracy': [0.723, 0.756, 0.812, 0.834, 0.867, 0.845, 0.924],
            'Performance_Drop': [0.201, 0.168, 0.112, 0.090, 0.057, 0.079, 0.000],
            'Modality_Contribution': [0.112, 0.145, 0.201, 0.179, 0.223, 0.189, 1.000],
            'F1_Score': [0.718, 0.743, 0.798, 0.823, 0.856, 0.834, 0.912],
            'Precision': [0.729, 0.769, 0.826, 0.845, 0.878, 0.856, 0.934],
            'Recall': [0.708, 0.718, 0.772, 0.802, 0.835, 0.813, 0.891]
        })
        
        # Audio-Specific Metrics
        audio_metrics = pd.DataFrame({
            'Audio_Model': ['Wav2Vec2-Base', 'Wav2Vec2-Large', 'Whisper-Large-v3', 'AudioMAE', 'HuBERT-Large', 'Custom-AudioViT'],
            'WER': [0.087, 0.065, 0.045, 0.123, 0.098, 0.063],
            'BLEU_Score': [0.756, 0.789, 0.834, 0.689, 0.723, 0.798],
            'Semantic_Score': [0.823, 0.845, 0.867, 0.745, 0.789, 0.856],
            'Downstream_Boost': [0.123, 0.145, 0.187, 0.098, 0.145, 0.167],
            'Audio_Quality_SNR': [18.5, 21.2, 24.8, 16.3, 19.7, 22.1]
        })
        
        # Video Quality & Performance
        video_metrics = pd.DataFrame({
            'Video_Model': ['VideoMAE-Base', 'VideoMAE-Large', 'ViViT-Base', 'TimeSformer', 'X-CLIP', 'Custom-VideoViT'],
            'Input_Resolution': ['224×224', '224×224', '224×224', '224×224', '224×224', '384×384'],
            'FPS': [16, 16, 8, 8, 12, 24],
            'Feature_R2': [0.812, 0.834, 0.789, 0.743, 0.823, 0.856],
            'MSE': [0.067, 0.054, 0.098, 0.089, 0.054, 0.043],
            'Temporal_Alignment': [0.923, 0.934, 0.878, 0.845, 0.889, 0.945],
            'Motion_Capture': [0.867, 0.889, 0.823, 0.798, 0.845, 0.912]
        })
        
        # Text Processing Performance
        text_metrics = pd.DataFrame({
            'Text_Model': ['BERT-Base', 'BERT-Large', 'RoBERTa-Large', 'DeBERTa-v3', 'T5-Large', 'Custom-TextEncoder'],
            'Accuracy': [0.834, 0.867, 0.878, 0.889, 0.856, 0.892],
            'Precision': [0.823, 0.856, 0.867, 0.878, 0.845, 0.883],
            'Recall': [0.845, 0.878, 0.889, 0.901, 0.867, 0.901],
            'F1_Score': [0.834, 0.867, 0.878, 0.889, 0.856, 0.892],
            'Semantic_Contribution': [0.145, 0.178, 0.189, 0.201, 0.167, 0.212],
            'Processing_Speed_tokens_s': [1250, 890, 756, 623, 445, 1180]
        })
        
        # Fusion Quality Analysis
        fusion_metrics = pd.DataFrame({
            'Fusion_Method': ['Early Fusion', 'Late Fusion', 'Cross-Attention', 'Multi-Head Cross', 'Transformer Fusion', 'Custom Fusion'],
            'Joint_Performance': [0.823, 0.845, 0.867, 0.889, 0.912, 0.924],
            'Cross_Modality_Gain': [0.089, 0.112, 0.145, 0.167, 0.189, 0.201],
            'Embedding_Utility': [0.756, 0.789, 0.823, 0.856, 0.878, 0.892],
            'Computational_Cost': [1.2, 1.0, 2.1, 2.8, 3.5, 3.2],
            'Memory_Efficiency': [0.892, 0.945, 0.823, 0.789, 0.756, 0.801]
        })
        
        # External Benchmark Alignment
        external_benchmarks = pd.DataFrame({
            'Benchmark': ['Algonauts 2023', 'BOLD5000', 'NSD', 'GOD', 'DecNef', 'fMRI-Recon', 'BrainBench'],
            'Our_Score': [0.823, 0.767, 0.845, 0.789, 0.734, 0.812, 0.856],
            'SOTA_Score': [0.856, 0.798, 0.867, 0.823, 0.756, 0.834, 0.878],
            'Rank': [3, 4, 2, 3, 5, 2, 2],
            'Gap_to_SOTA': [-0.033, -0.031, -0.022, -0.034, -0.022, -0.022, -0.022],
            'Total_Participants': [847, 156, 234, 89, 67, 123, 445],
            'Percentile': [92.3, 85.7, 95.1, 88.9, 78.2, 94.3, 96.2]
        })
        
        # Efficiency Analysis
        efficiency_metrics = pd.DataFrame({
            'Model_Configuration': ['Lightweight', 'Standard', 'High-Performance', 'Ultra-Performance', 'Custom-Optimized'],
            'Training_Speed_samples_s': [45.2, 28.9, 12.3, 6.7, 18.9],
            'Inference_Speed_ms': [23.4, 45.2, 89.4, 156.7, 67.3],
            'Memory_Usage_GB': [4.2, 8.2, 16.8, 28.9, 12.1],
            'Energy_Consumption_W': [45, 78, 145, 234, 98],
            'Accuracy_Trade_off': [0.823, 0.867, 0.912, 0.924, 0.889],
            'Cost_Performance_Ratio': [19.6, 11.1, 6.3, 3.9, 9.1]
        })
        
        return {
            'model_comparison': model_comparison,
            'ablation_study': ablation_study,
            'audio_metrics': audio_metrics,
            'video_metrics': video_metrics,
            'text_metrics': text_metrics,
            'fusion_metrics': fusion_metrics,
            'external_benchmarks': external_benchmarks,
            'efficiency_metrics': efficiency_metrics
        }
    
    def create_primary_model_table(self, df: pd.DataFrame) -> GT:
        """Create comprehensive model comparison table."""
        
        return (
            GT(df)
            .tab_header(
                title=html("<strong>🧠 Multimodal Model Performance Comparison</strong>"),
                subtitle="Audio-Video-Transcript → Image Prediction Benchmarks"
            )
            .tab_spanner(
                label="🎯 Predictive Performance",
                columns=['fMRI_Accuracy', 'Classification_Acc', 'Regression_R2']
            )
            .tab_spanner(
                label="⚡ Efficiency Metrics",
                columns=['Training_Hours', 'Inference_ms', 'Memory_GB']
            )
            .tab_spanner(
                label="🔧 Availability & Usability",
                columns=['Code_Available', 'Pretrained', 'Ease_of_Use']
            )
            .fmt_number(
                columns=['fMRI_Accuracy', 'Classification_Acc', 'Regression_R2'],
                decimals=3
            )
            .fmt_number(
                columns=['Training_Hours', 'Inference_ms', 'Memory_GB', 'Ease_of_Use'],
                decimals=1
            )
            .data_color(
                columns=['fMRI_Accuracy', 'Classification_Acc', 'Regression_R2'],
                palette=[self.colors['very_poor'], self.colors['poor'], self.colors['average'], 
                        self.colors['good'], self.colors['excellent']],
                domain=[0.5, 1.0]
            )
            .data_color(
                columns=['Ease_of_Use'],
                palette=[self.colors['very_poor'], self.colors['excellent']],
                domain=[1, 10]
            )
            .tab_style(
                style=[style.fill(color=self.colors['header_bg']), 
                      style.text(color='white', weight='bold')],
                locations=loc.column_header()
            )
            #.tab_footnote(
             #   footnote="fMRI_Accuracy: Correlation with brain activity patterns",
              #  locations=loc.column_header(columns=['fMRI_Accuracy'])
            #)
            #.tab_footnote(
             #   footnote="Ease_of_Use: 1-10 scale (10=easiest)",
              #  locations=loc.column_header(columns=['Ease_of_Use'])
            #)
        )
    
    def create_ablation_table(self, df: pd.DataFrame) -> GT:
        """Create modality ablation study table."""
        
        return (
            GT(df)
            .tab_header(
                title=html("<strong>🔬 Modality Ablation Study</strong>"),
                subtitle="Impact of different input modality combinations"
            )
            .fmt_number(
                columns=['Accuracy', 'F1_Score', 'Precision', 'Recall'],
                decimals=3
            )
            .fmt_percent(
                columns=['Performance_Drop', 'Modality_Contribution'],
                decimals=1
            )
            .data_color(
                columns=['Accuracy', 'F1_Score'],
                palette=[self.colors['poor'], self.colors['average'], self.colors['good'], self.colors['excellent']],
                domain=[0.7, 1.0]
            )
            .data_color(
                columns=['Performance_Drop'],
                palette=[self.colors['excellent'], self.colors['poor']],
                domain=[0.0, 0.25],
                reverse=True
            )
            .tab_style(
                style=[style.fill(color=self.colors['header_bg']), 
                      style.text(color='white', weight='bold')],
                locations=loc.column_header()
            )
            #.tab_footnote(
            #    footnote="Performance_Drop: Decrease from best multimodal performance",
            #    locations=loc.column_header(columns=['Performance_Drop'])
            #)
        )
    
    def create_audio_metrics_table(self, df: pd.DataFrame) -> GT:
        """Create audio-specific performance table."""
        
        return (
            GT(df)
            .tab_header(
                title=html("<strong>🎵 Audio Processing Performance</strong>"),
                subtitle="Audio model evaluation for downstream image prediction"
            )
            .fmt_number(
                columns=['BLEU_Score', 'Semantic_Score', 'Downstream_Boost', 'Audio_Quality_SNR'],
                decimals=3
            )
            .fmt_number(
                columns=['WER'],
                decimals=3
            )
            .data_color(
                columns=['BLEU_Score', 'Semantic_Score', 'Downstream_Boost', 'Audio_Quality_SNR'],
                palette=[self.colors['poor'], self.colors['excellent']],
                domain=[0.5, 1.0]
            )
            .data_color(
                columns=['WER'],
                palette=[self.colors['excellent'], self.colors['poor']],
                domain=[0.0, 0.15],
                reverse=True
            )
            .tab_style(
                style=[style.fill(color=self.colors['header_bg']), 
                      style.text(color='white', weight='bold')],
                locations=loc.column_header()
            )
            #.tab_footnote(
             #   footnote="WER: Word Error Rate (lower is better)",
             #   locations=loc.column_header(columns=['WER'])
           # )
            #.tab_footnote(
             #   footnote="SNR: Signal-to-Noise Ratio in dB",
            #    locations=loc.column_header(columns=['Audio_Quality_SNR'])
            #)
        )
    
    def create_video_metrics_table(self, df: pd.DataFrame) -> GT:
        """Create video processing performance table."""
        
        return (
            GT(df)
            .tab_header(
                title=html("<strong>🎬 Video Processing Performance</strong>"),
                subtitle="Video model evaluation with resolution and temporal metrics"
            )
            .fmt_number(
                columns=['Feature_R2', 'MSE', 'Temporal_Alignment', 'Motion_Capture'],
                decimals=3
            )
            .data_color(
                columns=['Feature_R2', 'Temporal_Alignment', 'Motion_Capture'],
                palette=[self.colors['poor'], self.colors['excellent']],
                domain=[0.7, 1.0]
            )
            .data_color(
                columns=['MSE'],
                palette=[self.colors['excellent'], self.colors['poor']],
                domain=[0.0, 0.1],
                reverse=True
            )
            .tab_style(
                style=[style.fill(color=self.colors['header_bg']), 
                      style.text(color='white', weight='bold')],
                locations=loc.column_header()
            )
            #.tab_footnote(
            #    footnote="MSE: Mean Squared Error (lower is better)",
            #    locations=loc.column_header(columns=['MSE'])
            #)
        )
    
    def create_fusion_quality_table(self, df: pd.DataFrame) -> GT:
        """Create fusion method comparison table."""
        
        return (
            GT(df)
            .tab_header(
                title=html("<strong>🔗 Multimodal Fusion Analysis</strong>"),
                subtitle="Cross-modality integration performance comparison"
            )
            .fmt_number(
                columns=['Joint_Performance', 'Cross_Modality_Gain', 'Embedding_Utility', 'Memory_Efficiency'],
                decimals=3
            )
            .fmt_number(
                columns=['Computational_Cost'],
                decimals=1
            )
            .data_color(
                columns=['Joint_Performance', 'Cross_Modality_Gain', 'Embedding_Utility', 'Memory_Efficiency'],
                palette=[self.colors['poor'], self.colors['excellent']],
                domain=[0.7, 1.0]
            )
            .data_color(
                columns=['Computational_Cost'],
                palette=[self.colors['excellent'], self.colors['poor']],
                domain=[1.0, 4.0],
                reverse=True
            )
            .tab_style(
                style=[style.fill(color=self.colors['header_bg']), 
                      style.text(color='white', weight='bold')],
                locations=loc.column_header()
            )
            #.tab_footnote(
            #    footnote="Computational_Cost: Relative to baseline (1.0 = baseline)",
            #    locations=loc.column_header(columns=['Computational_Cost'])
            #)
        )
    
    def create_external_benchmark_table(self, df: pd.DataFrame) -> GT:
        """Create external benchmark alignment table."""
        
        return (
            GT(df)
            .tab_header(
                title=html("<strong>🏆 External Benchmark Performance</strong>"),
                subtitle="Alignment with established neuroimaging and AI benchmarks"
            )
            .fmt_number(
                columns=['Our_Score', 'SOTA_Score', 'Gap_to_SOTA'],
                decimals=3
            )
            .fmt_number(
                columns=['Percentile'],
                decimals=1
            )
            .cols_label(
                Our_Score="Our Score",
                SOTA_Score="SOTA Score",
                Gap_to_SOTA="Gap to SOTA",
                Total_Participants="Participants"
            )
            .data_color(
                columns=['Our_Score', 'SOTA_Score'],
                palette=[self.colors['poor'], self.colors['excellent']],
                domain=[0.7, 0.9]
            )
            .data_color(
                columns=['Percentile'],
                palette=[self.colors['poor'], self.colors['excellent']],
                domain=[70, 100]
            )
            .tab_style(
                style=[style.fill(color=self.colors['header_bg']), 
                      style.text(color='white', weight='bold')],
                locations=loc.column_header()
            )
            #.tab_footnote(
             #   footnote="SOTA: State-of-the-Art performance on each benchmark",
              #  locations=loc.column_header(columns=['SOTA_Score'])
            #)
        )
    
    def create_efficiency_table(self, df: pd.DataFrame) -> GT:
        """Create efficiency analysis table."""
        
        return (
            GT(df)
            .tab_header(
                title=html("<strong>⚡ Model Efficiency Analysis</strong>"),
                subtitle="Training speed, inference speed, and resource utilization"
            )
            .fmt_number(
                columns=['Training_Speed_samples_s', 'Inference_Speed_ms', 'Memory_Usage_GB', 
                        'Energy_Consumption_W', 'Accuracy_Trade_off', 'Cost_Performance_Ratio'],
                decimals=1
            )
            .data_color(
                columns=['Training_Speed_samples_s', 'Cost_Performance_Ratio'],
                palette=[self.colors['poor'], self.colors['excellent']],
                domain=[5, 50]
            )
            .data_color(
                columns=['Inference_Speed_ms', 'Memory_Usage_GB', 'Energy_Consumption_W'],
                palette=[self.colors['excellent'], self.colors['poor']],
                domain=[0, 300],
                reverse=True
            )
            .data_color(
                columns=['Accuracy_Trade_off'],
                palette=[self.colors['poor'], self.colors['excellent']],
                domain=[0.8, 1.0]
            )
            .tab_style(style=[style.fill(color=self.colors['header_bg']), 
                style.text(color='white', weight='bold')],
                locations=loc.column_header()
        )

            #.tab_footnote(
            #    footnote="Cost_Performance_Ratio: Higher values indicate better efficiency",
            #    locations=loc.column_header(columns=['Cost_Performance_Ratio'])
            #)
        )
    
    def generate_all_tables(self) -> Dict[str, GT]:
        """Generate all benchmark tables."""
        data = self.generate_benchmark_data()
        
        tables = {
            'model_comparison': self.create_primary_model_table(data['model_comparison']),
            'ablation_study': self.create_ablation_table(data['ablation_study']),
            'audio_metrics': self.create_audio_metrics_table(data['audio_metrics']),
            'video_metrics': self.create_video_metrics_table(data['video_metrics']),
            'fusion_quality': self.create_fusion_quality_table(data['fusion_metrics']),
            'external_benchmarks': self.create_external_benchmark_table(data['external_benchmarks']),
            'efficiency_analysis': self.create_efficiency_table(data['efficiency_metrics'])
        }
        
        return tables

# Usage Example and Execution
def main():
    """Main execution function with comprehensive benchmark suite."""
    
    print("🧠 Generating Multimodal ML Benchmark Visualization Suite...")
    print("=" * 60)
    
    # Initialize visualizer
    visualizer = MultimodalBenchmarkVisualizer()
    
    # Generate all tables
    tables = visualizer.generate_all_tables()
    
    # Display each table
    table_descriptions = {
        'model_comparison': "Primary Model Performance Comparison",
        'ablation_study': "Modality Ablation Study Results", 
        'audio_metrics': "Audio Processing Performance Metrics",
        'video_metrics': "Video Processing Quality Analysis",
        'fusion_quality': "Multimodal Fusion Performance",
        'external_benchmarks': "External Benchmark Alignment",
        'efficiency_analysis': "Model Efficiency & Resource Usage"
    }
    
    for table_name, description in table_descriptions.items():
        print(f"\n📊 {description}")
        print("-" * 40)
        print(tables[table_name])
        print("\n")
    
    print("✅ Benchmark visualization suite completed successfully!")
    print(f"📈 Generated {len(tables)} professional benchmark tables")
    
    # Performance summary
    print("\n🎯 Key Findings Summary:")
    print("• MM-Fusion-XL achieves highest accuracy (92.4%)")
    print("• All modalities provide significant performance boost")
    print("• Cross-attention fusion shows best cross-modality gains")
    print("• Strong alignment with external benchmarks (85-96th percentile)")
    print("• Custom optimizations balance performance and efficiency")

if __name__ == "__main__":
    main()
# Out:
# 🧠 Generating Multimodal ML Benchmark Visualization Suite...
# ============================================================
#
# 📊 Primary Model Performance Comparison
# ----------------------------------------
# GT(_tbl_data=          Model  fMRI_Accuracy  Classification_Acc  Regression_R2  \
# 0    AudioViT-L          0.847               0.834          0.720
# 1    VideoMAE-B          0.823               0.798          0.680
# 2    BERT-Large          0.789               0.765          0.590
# 3    CLIP-ViT-B          0.891               0.856          0.810
# 4  MM-Fusion-XL          0.924               0.912          0.870
# 5        GPT-4V          0.912               0.898          0.845
# 6     LLaVA-1.5          0.889               0.873          0.823
#
#    Training_Hours  Inference_ms  Memory_GB Code_Available Pretrained  \
# 0            12.3          45.2        8.2              ✓          ✓
# 1             8.7          23.1        6.1              ✓          ✓
# 2             4.2           8.9        3.4              ✓          ✓
# 3            15.6          67.3       11.7              ✓          ✓
# 4            28.9          89.4       16.8              ✓          ✗
# 5            45.2         156.7       24.3              ✗          ✓
# 6            32.1         123.4       19.2              ✓          ✓
#
#    Ease_of_Use
# 0          8.5
# 1          9.2
# 2          9.8
# 3          7.8
# 4          6.5
# 5          5.2
# 6          7.1  , _body=<great_tables._gt_data.Body object at 0x00000254748E1C50>, _boxhead=Boxhead([ColInfo(var='Model', type=<ColInfoTypeEnum.default: 1>, column_label='Model', column_align='left', column_width=None), ColInfo(var='fMRI_Accuracy', type=<ColInfoTypeEnum.default: 1>, column_label='fMRI_Accuracy', column_align='right', column_width=None), ColInfo(var='Classification_Acc', type=<ColInfoTypeEnum.default: 1>, column_label='Classification_Acc', column_align='right', column_width=None), ColInfo(var='Regression_R2', type=<ColInfoTypeEnum.default: 1>, column_label='Regression_R2', column_align='right', column_width=None), ColInfo(var='Training_Hours', type=<ColInfoTypeEnum.default: 1>, column_label='Training_Hours', column_align='right', column_width=None), ColInfo(var='Inference_ms', type=<ColInfoTypeEnum.default: 1>, column_label='Inference_ms', column_align='right', column_width=None), ColInfo(var='Memory_GB', type=<ColInfoTypeEnum.default: 1>, column_label='Memory_GB', column_align='right', column_width=None), ColInfo(var='Code_Available', type=<ColInfoTypeEnum.default: 1>, column_label='Code_Available', column_align='left', column_width=None), ColInfo(var='Pretrained', type=<ColInfoTypeEnum.default: 1>, column_label='Pretrained', column_align='left', column_width=None), ColInfo(var='Ease_of_Use', type=<ColInfoTypeEnum.default: 1>, column_label='Ease_of_Use', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000254748CA550>, _spanners=Spanners([SpannerInfo(spanner_id='🎯 Predictive Performance', spanner_level=0, spanner_label='🎯 Predictive Performance', spanner_units=None, spanner_pattern=None, vars=['fMRI_Accuracy', 'Classification_Acc', 'Regression_R2'], built=None), SpannerInfo(spanner_id='⚡ Efficiency Metrics', spanner_level=0, spanner_label='⚡ Efficiency Metrics', spanner_units=None, spanner_pattern=None, vars=['Training_Hours', 'Inference_ms', 'Memory_GB'], built=None), SpannerInfo(spanner_id='🔧 Availability & Usability', spanner_level=0, spanner_label='🔧 Availability & Usability', spanner_units=None, spanner_pattern=None, vars=['Code_Available', 'Pretrained', 'Ease_of_Use'], built=None)]), _heading=Heading(title=Html(text='<strong>🧠 Multimodal Model Performance Comparison</strong>'), subtitle='Audio-Video-Transcript → Image Prediction Benchmarks', preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='fMRI_Accuracy', rows=[0], mask=None), grpname=None, colname='fMRI_Accuracy', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#60cf27')]), StyleInfo(locname=LocBody(columns='fMRI_Accuracy', rows=[1], mask=None), grpname=None, colname='fMRI_Accuracy', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#87d11d')]), StyleInfo(locname=LocBody(columns='fMRI_Accuracy', rows=[2], mask=None), grpname=None, colname='fMRI_Accuracy', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#bfd410')]), StyleInfo(locname=LocBody(columns='fMRI_Accuracy', rows=[3], mask=None), grpname=None, colname='fMRI_Accuracy', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#31c537')]), StyleInfo(locname=LocBody(columns='fMRI_Accuracy', rows=[4], mask=None), grpname=None, colname='fMRI_Accuracy', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align ...
#
#
#
# 📊 Modality Ablation Study Results
# ----------------------------------------
# GT(_tbl_data=  Modality_Combination  Accuracy  Performance_Drop  Modality_Contribution  \
# 0           Audio Only     0.723             0.201                  0.112
# 1           Video Only     0.756             0.168                  0.145
# 2            Text Only     0.812             0.112                  0.201
# 3          Audio+Video     0.834             0.090                  0.179
# 4           Audio+Text     0.867             0.057                  0.223
# 5           Video+Text     0.845             0.079                  0.189
# 6       All Modalities     0.924             0.000                  1.000
#
#    F1_Score  Precision  Recall
# 0     0.718      0.729   0.708
# 1     0.743      0.769   0.718
# 2     0.798      0.826   0.772
# 3     0.823      0.845   0.802
# 4     0.856      0.878   0.835
# 5     0.834      0.856   0.813
# 6     0.912      0.934   0.891  , _body=<great_tables._gt_data.Body object at 0x00000254748AC3D0>, _boxhead=Boxhead([ColInfo(var='Modality_Combination', type=<ColInfoTypeEnum.default: 1>, column_label='Modality_Combination', column_align='left', column_width=None), ColInfo(var='Accuracy', type=<ColInfoTypeEnum.default: 1>, column_label='Accuracy', column_align='right', column_width=None), ColInfo(var='Performance_Drop', type=<ColInfoTypeEnum.default: 1>, column_label='Performance_Drop', column_align='right', column_width=None), ColInfo(var='Modality_Contribution', type=<ColInfoTypeEnum.default: 1>, column_label='Modality_Contribution', column_align='right', column_width=None), ColInfo(var='F1_Score', type=<ColInfoTypeEnum.default: 1>, column_label='F1_Score', column_align='right', column_width=None), ColInfo(var='Precision', type=<ColInfoTypeEnum.default: 1>, column_label='Precision', column_align='right', column_width=None), ColInfo(var='Recall', type=<ColInfoTypeEnum.default: 1>, column_label='Recall', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000254748B7610>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<strong>🔬 Modality Ablation Study</strong>'), subtitle='Impact of different input modality combinations', preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='Accuracy', rows=[0], mask=None), grpname=None, colname='Accuracy', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ff7e37')]), StyleInfo(locname=LocBody(columns='Accuracy', rows=[1], mask=None), grpname=None, colname='Accuracy', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ffa41f')]), StyleInfo(locname=LocBody(columns='Accuracy', rows=[2], mask=None), grpname=None, colname='Accuracy', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#e6d606')]), StyleInfo(locname=LocBody(columns='Accuracy', rows=[3], mask=None), grpname=None, colname='Accuracy', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#b9d411')]), StyleInfo(locname=LocBody(columns='Accuracy', rows=[4], mask=None), grpname=None, colname='Accuracy', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#76d022')]), StyleInfo(locname=LocBody(columns='Accuracy', rows=[5], mask=None), grpname=None, colname='Accuracy', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#a3d217')]), StyleInfo(locname=LocBody(columns='Accuracy', rows=[6], mask=None), grpname=None, colname='Accuracy', rownum=6, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#31bd3b')]), StyleInfo(locname=LocBody(columns='F1_Score', rows=[0], mask=None), grpname=None, colname='F1_Score', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=N ...
#
#
#
# 📊 Audio Processing Performance Metrics
# ----------------------------------------
# GT(_tbl_data=        Audio_Model    WER  BLEU_Score  Semantic_Score  Downstream_Boost  \
# 0     Wav2Vec2-Base  0.087       0.756           0.823             0.123
# 1    Wav2Vec2-Large  0.065       0.789           0.845             0.145
# 2  Whisper-Large-v3  0.045       0.834           0.867             0.187
# 3          AudioMAE  0.123       0.689           0.745             0.098
# 4      HuBERT-Large  0.098       0.723           0.789             0.145
# 5   Custom-AudioViT  0.063       0.798           0.856             0.167
#
#    Audio_Quality_SNR
# 0               18.5
# 1               21.2
# 2               24.8
# 3               16.3
# 4               19.7
# 5               22.1  , _body=<great_tables._gt_data.Body object at 0x000002546B98F010>, _boxhead=Boxhead([ColInfo(var='Audio_Model', type=<ColInfoTypeEnum.default: 1>, column_label='Audio_Model', column_align='left', column_width=None), ColInfo(var='WER', type=<ColInfoTypeEnum.default: 1>, column_label='WER', column_align='right', column_width=None), ColInfo(var='BLEU_Score', type=<ColInfoTypeEnum.default: 1>, column_label='BLEU_Score', column_align='right', column_width=None), ColInfo(var='Semantic_Score', type=<ColInfoTypeEnum.default: 1>, column_label='Semantic_Score', column_align='right', column_width=None), ColInfo(var='Downstream_Boost', type=<ColInfoTypeEnum.default: 1>, column_label='Downstream_Boost', column_align='right', column_width=None), ColInfo(var='Audio_Quality_SNR', type=<ColInfoTypeEnum.default: 1>, column_label='Audio_Quality_SNR', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x00000254743DEF10>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<strong>🎵 Audio Processing Performance</strong>'), subtitle='Audio model evaluation for downstream image prediction', preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='BLEU_Score', rows=[0], mask=None), grpname=None, colname='BLEU_Score', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#94774f')]), StyleInfo(locname=LocBody(columns='BLEU_Score', rows=[1], mask=None), grpname=None, colname='BLEU_Score', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#867a50')]), StyleInfo(locname=LocBody(columns='BLEU_Score', rows=[2], mask=None), grpname=None, colname='BLEU_Score', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#737e52')]), StyleInfo(locname=LocBody(columns='BLEU_Score', rows=[3], mask=None), grpname=None, colname='BLEU_Score', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#b0724d')]), StyleInfo(locname=LocBody(columns='BLEU_Score', rows=[4], mask=None), grpname=None, colname='BLEU_Score', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#a2754e')]), StyleInfo(locname=LocBody(columns='BLEU_Score', rows=[5], mask=None), grpname=None, colname='BLEU_Score', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#827b51')]), StyleInfo(locname=LocBody(columns='Semantic_Score', rows=[0], mask=None), grpname=None, colname='Semantic_Score', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#787d51')]), StyleInfo(locname=LocBody(columns='Semantic_Score', rows=[1], mask=None), grpname=None, colname='Semantic_Score', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#6f7f52')]), StyleInfo(locname=LocBody(columns='Semantic_Score', ro ...
#
#
#
# 📊 Video Processing Quality Analysis
# ----------------------------------------
# GT(_tbl_data=       Video_Model Input_Resolution  FPS  Feature_R2    MSE  \
# 0    VideoMAE-Base          224×224   16       0.812  0.067
# 1   VideoMAE-Large          224×224   16       0.834  0.054
# 2       ViViT-Base          224×224    8       0.789  0.098
# 3      TimeSformer          224×224    8       0.743  0.089
# 4           X-CLIP          224×224   12       0.823  0.054
# 5  Custom-VideoViT          384×384   24       0.856  0.043
#
#    Temporal_Alignment  Motion_Capture
# 0               0.923           0.867
# 1               0.934           0.889
# 2               0.878           0.823
# 3               0.845           0.798
# 4               0.889           0.845
# 5               0.945           0.912  , _body=<great_tables._gt_data.Body object at 0x00000254743E9C10>, _boxhead=Boxhead([ColInfo(var='Video_Model', type=<ColInfoTypeEnum.default: 1>, column_label='Video_Model', column_align='left', column_width=None), ColInfo(var='Input_Resolution', type=<ColInfoTypeEnum.default: 1>, column_label='Input_Resolution', column_align='left', column_width=None), ColInfo(var='FPS', type=<ColInfoTypeEnum.default: 1>, column_label='FPS', column_align='right', column_width=None), ColInfo(var='Feature_R2', type=<ColInfoTypeEnum.default: 1>, column_label='Feature_R2', column_align='right', column_width=None), ColInfo(var='MSE', type=<ColInfoTypeEnum.default: 1>, column_label='MSE', column_align='right', column_width=None), ColInfo(var='Temporal_Alignment', type=<ColInfoTypeEnum.default: 1>, column_label='Temporal_Alignment', column_align='right', column_width=None), ColInfo(var='Motion_Capture', type=<ColInfoTypeEnum.default: 1>, column_label='Motion_Capture', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000002546B98EE50>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<strong>🎬 Video Processing Performance</strong>'), subtitle='Video model evaluation with resolution and temporal metrics', preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='Feature_R2', rows=[0], mask=None), grpname=None, colname='Feature_R2', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#b1724d')]), StyleInfo(locname=LocBody(columns='Feature_R2', rows=[1], mask=None), grpname=None, colname='Feature_R2', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#a2754e')]), StyleInfo(locname=LocBody(columns='Feature_R2', rows=[2], mask=None), grpname=None, colname='Feature_R2', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#c16f4c')]), StyleInfo(locname=LocBody(columns='Feature_R2', rows=[3], mask=None), grpname=None, colname='Feature_R2', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#e16949')]), StyleInfo(locname=LocBody(columns='Feature_R2', rows=[4], mask=None), grpname=None, colname='Feature_R2', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#a9734e')]), StyleInfo(locname=LocBody(columns='Feature_R2', rows=[5], mask=None), grpname=None, colname='Feature_R2', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#92784f')]), StyleInfo(locname=LocBody(columns='Temporal_Alignment', rows=[0], mask=None), grpname=None, colname='Temporal_Alignment', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#648153')]), StyleInfo(locname=LocBody(columns='Temporal_Alignment', rows=[1], mask=None), grpname=None, colname='Temporal_Alignment', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=No ...
#
#
#
# 📊 Multimodal Fusion Performance
# ----------------------------------------
# GT(_tbl_data=        Fusion_Method  Joint_Performance  Cross_Modality_Gain  \
# 0        Early Fusion              0.823                0.089
# 1         Late Fusion              0.845                0.112
# 2     Cross-Attention              0.867                0.145
# 3    Multi-Head Cross              0.889                0.167
# 4  Transformer Fusion              0.912                0.189
# 5       Custom Fusion              0.924                0.201
#
#    Embedding_Utility  Computational_Cost  Memory_Efficiency
# 0              0.756                 1.2              0.892
# 1              0.789                 1.0              0.945
# 2              0.823                 2.1              0.823
# 3              0.856                 2.8              0.789
# 4              0.878                 3.5              0.756
# 5              0.892                 3.2              0.801  , _body=<great_tables._gt_data.Body object at 0x00000254748A9790>, _boxhead=Boxhead([ColInfo(var='Fusion_Method', type=<ColInfoTypeEnum.default: 1>, column_label='Fusion_Method', column_align='left', column_width=None), ColInfo(var='Joint_Performance', type=<ColInfoTypeEnum.default: 1>, column_label='Joint_Performance', column_align='right', column_width=None), ColInfo(var='Cross_Modality_Gain', type=<ColInfoTypeEnum.default: 1>, column_label='Cross_Modality_Gain', column_align='right', column_width=None), ColInfo(var='Embedding_Utility', type=<ColInfoTypeEnum.default: 1>, column_label='Embedding_Utility', column_align='right', column_width=None), ColInfo(var='Computational_Cost', type=<ColInfoTypeEnum.default: 1>, column_label='Computational_Cost', column_align='right', column_width=None), ColInfo(var='Memory_Efficiency', type=<ColInfoTypeEnum.default: 1>, column_label='Memory_Efficiency', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000002546BC917D0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<strong>🔗 Multimodal Fusion Analysis</strong>'), subtitle='Cross-modality integration performance comparison', preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='Joint_Performance', rows=[0], mask=None), grpname=None, colname='Joint_Performance', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#a9734e')]), StyleInfo(locname=LocBody(columns='Joint_Performance', rows=[1], mask=None), grpname=None, colname='Joint_Performance', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#9a764f')]), StyleInfo(locname=LocBody(columns='Joint_Performance', rows=[2], mask=None), grpname=None, colname='Joint_Performance', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#8b7950')]), StyleInfo(locname=LocBody(columns='Joint_Performance', rows=[3], mask=None), grpname=None, colname='Joint_Performance', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#7b7c51')]), StyleInfo(locname=LocBody(columns='Joint_Performance', rows=[4], mask=None), grpname=None, colname='Joint_Performance', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#6b7f52')]), StyleInfo(locname=LocBody(columns='Joint_Performance', rows=[5], mask=None), grpname=None, colname='Joint_Performance', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#638153')]), StyleInfo(locname=LocBody(columns='Cross_Modality_Gain', rows=[0], mask=None), grpname=None, colname='Cross_Modality_Gain', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#808080')]), StyleInfo(locname=LocBody(columns='Cross_Modality_Gain', rows=[1], mask=None), grpname=None, colname='Cross_Modality_Gain', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align= ...
#
#
#
# 📊 External Benchmark Alignment
# ----------------------------------------
# GT(_tbl_data=        Benchmark  Our_Score  SOTA_Score  Rank  Gap_to_SOTA  \
# 0  Algonauts 2023      0.823       0.856     3       -0.033
# 1        BOLD5000      0.767       0.798     4       -0.031
# 2             NSD      0.845       0.867     2       -0.022
# 3             GOD      0.789       0.823     3       -0.034
# 4          DecNef      0.734       0.756     5       -0.022
# 5      fMRI-Recon      0.812       0.834     2       -0.022
# 6      BrainBench      0.856       0.878     2       -0.022
#
#    Total_Participants  Percentile
# 0                 847        92.3
# 1                 156        85.7
# 2                 234        95.1
# 3                  89        88.9
# 4                  67        78.2
# 5                 123        94.3
# 6                 445        96.2  , _body=<great_tables._gt_data.Body object at 0x0000025474929350>, _boxhead=Boxhead([ColInfo(var='Benchmark', type=<ColInfoTypeEnum.default: 1>, column_label='Benchmark', column_align='left', column_width=None), ColInfo(var='Our_Score', type=<ColInfoTypeEnum.default: 1>, column_label='Our Score', column_align='right', column_width=None), ColInfo(var='SOTA_Score', type=<ColInfoTypeEnum.default: 1>, column_label='SOTA Score', column_align='right', column_width=None), ColInfo(var='Rank', type=<ColInfoTypeEnum.default: 1>, column_label='Rank', column_align='right', column_width=None), ColInfo(var='Gap_to_SOTA', type=<ColInfoTypeEnum.default: 1>, column_label='Gap to SOTA', column_align='right', column_width=None), ColInfo(var='Total_Participants', type=<ColInfoTypeEnum.default: 1>, column_label='Participants', column_align='right', column_width=None), ColInfo(var='Percentile', type=<ColInfoTypeEnum.default: 1>, column_label='Percentile', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000002547492BE10>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<strong>🏆 External Benchmark Performance</strong>'), subtitle='Alignment with established neuroimaging and AI benchmarks', preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='Our_Score', rows=[0], mask=None), grpname=None, colname='Our_Score', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#7e7c51')]), StyleInfo(locname=LocBody(columns='Our_Score', rows=[1], mask=None), grpname=None, colname='Our_Score', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#b9704c')]), StyleInfo(locname=LocBody(columns='Our_Score', rows=[2], mask=None), grpname=None, colname='Our_Score', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#678053')]), StyleInfo(locname=LocBody(columns='Our_Score', rows=[3], mask=None), grpname=None, colname='Our_Score', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#a2754e')]), StyleInfo(locname=LocBody(columns='Our_Score', rows=[4], mask=None), grpname=None, colname='Our_Score', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#db6a4a')]), StyleInfo(locname=LocBody(columns='Our_Score', rows=[5], mask=None), grpname=None, colname='Our_Score', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#8a7950')]), StyleInfo(locname=LocBody(columns='Our_Score', rows=[6], mask=None), grpname=None, colname='Our_Score', rownum=6, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#5c8253')]), StyleInfo(locname=LocBody(columns='SOTA_Score', rows=[0], mask=None), grpname=None, colname='SOTA_Score', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=Non ...
#
#
#
# 📊 Model Efficiency & Resource Usage
# ----------------------------------------
# GT(_tbl_data=  Model_Configuration  Training_Speed_samples_s  Inference_Speed_ms  \
# 0         Lightweight                      45.2                23.4
# 1            Standard                      28.9                45.2
# 2    High-Performance                      12.3                89.4
# 3   Ultra-Performance                       6.7               156.7
# 4    Custom-Optimized                      18.9                67.3
#
#    Memory_Usage_GB  Energy_Consumption_W  Accuracy_Trade_off  \
# 0              4.2                    45               0.823
# 1              8.2                    78               0.867
# 2             16.8                   145               0.912
# 3             28.9                   234               0.924
# 4             12.1                    98               0.889
#
#    Cost_Performance_Ratio
# 0                    19.6
# 1                    11.1
# 2                     6.3
# 3                     3.9
# 4                     9.1  , _body=<great_tables._gt_data.Body object at 0x000002547491A810>, _boxhead=Boxhead([ColInfo(var='Model_Configuration', type=<ColInfoTypeEnum.default: 1>, column_label='Model_Configuration', column_align='left', column_width=None), ColInfo(var='Training_Speed_samples_s', type=<ColInfoTypeEnum.default: 1>, column_label='Training_Speed_samples_s', column_align='right', column_width=None), ColInfo(var='Inference_Speed_ms', type=<ColInfoTypeEnum.default: 1>, column_label='Inference_Speed_ms', column_align='right', column_width=None), ColInfo(var='Memory_Usage_GB', type=<ColInfoTypeEnum.default: 1>, column_label='Memory_Usage_GB', column_align='right', column_width=None), ColInfo(var='Energy_Consumption_W', type=<ColInfoTypeEnum.default: 1>, column_label='Energy_Consumption_W', column_align='right', column_width=None), ColInfo(var='Accuracy_Trade_off', type=<ColInfoTypeEnum.default: 1>, column_label='Accuracy_Trade_off', column_align='right', column_width=None), ColInfo(var='Cost_Performance_Ratio', type=<ColInfoTypeEnum.default: 1>, column_label='Cost_Performance_Ratio', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000025474924710>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<strong>⚡ Model Efficiency Analysis</strong>'), subtitle='Training speed, inference speed, and resource utilization', preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='Training_Speed_samples_s', rows=[0], mask=None), grpname=None, colname='Training_Speed_samples_s', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#448755')]), StyleInfo(locname=LocBody(columns='Training_Speed_samples_s', rows=[1], mask=None), grpname=None, colname='Training_Speed_samples_s', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#90784f')]), StyleInfo(locname=LocBody(columns='Training_Speed_samples_s', rows=[2], mask=None), grpname=None, colname='Training_Speed_samples_s', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#dd694a')]), StyleInfo(locname=LocBody(columns='Training_Speed_samples_s', rows=[3], mask=None), grpname=None, colname='Training_Speed_samples_s', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#f76548')]), StyleInfo(locname=LocBody(columns='Training_Speed_samples_s', rows=[4], mask=None), grpname=None, colname='Training_Speed_samples_s', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#be6f4c')]), StyleInfo(locname=LocBody(columns='Cost_Performance_Ratio', rows=[0], mask=None), grpname=None, colname='Cost_Performance_Ratio', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#bb704c')]), StyleInfo(locname=LocBody(columns='Cost_Performance_Ratio', rows=[1], mask=None), grpname=None, colname='Cost_Performance_Ratio', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyle ...
#
#
# ✅ Benchmark visualization suite completed successfully!
# 📈 Generated 7 professional benchmark tables
#
# 🎯 Key Findings Summary:
# • MM-Fusion-XL achieves highest accuracy (92.4%)
# • All modalities provide significant performance boost
# • Cross-attention fusion shows best cross-modality gains
# • Strong alignment with external benchmarks (85-96th percentile)
# • Custom optimizations balance performance and efficiency

# %%
visualizer = MultimodalBenchmarkVisualizer()
tables = visualizer.generate_all_tables()


# Access one specific table
model_comparison_table = tables['model_comparison']
ablation_table = tables['ablation_study']
audio_metrics_table = tables['audio_metrics']
video_metrics_table = tables['video_metrics']
fusion_table = tables['fusion_quality']
external_benchmarks_table = tables['external_benchmarks']
efficiency_analysis_table = tables['efficiency_analysis']

# Print the GT object (will show internal representation, not styled HTML)

video_metrics_table.show()
fusion_table.show()
external_benchmarks_table.show()
efficiency_analysis_table.show()
# Out:
# <div id="zmxduihwzs" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #zmxduihwzs table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #zmxduihwzs thead, tbody, tfoot, tr, td, th { border-style: none !important; }
#  tr { background-color: transparent !important; }
# #zmxduihwzs p { margin: 0 !important; padding: 0 !important; }
#  #zmxduihwzs .gt_table { display: table !important; border-collapse: collapse !important; line-height: normal !important; margin-left: auto !important; margin-right: auto !important; color: #333333 !important; font-size: 16px !important; font-weight: normal !important; font-style: normal !important; background-color: #FFFFFF !important; width: auto !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #A8A8A8 !important; border-right-style: none !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #A8A8A8 !important; border-left-style: none !important; border-left-width: 2px !important; border-left-color: #D3D3D3 !important; }
#  #zmxduihwzs .gt_caption { padding-top: 4px !important; padding-bottom: 4px !important; }
#  #zmxduihwzs .gt_title { color: #333333 !important; font-size: 125% !important; font-weight: initial !important; padding-top: 4px !important; padding-bottom: 4px !important; padding-left: 5px !important; padding-right: 5px !important; border-bottom-color: #FFFFFF !important; border-bottom-width: 0 !important; }
#  #zmxduihwzs .gt_subtitle { color: #333333 !important; font-size: 85% !important; font-weight: initial !important; padding-top: 3px !important; padding-bottom: 5px !important; padding-left: 5px !important; padding-right: 5px !important; border-top-color: #FFFFFF !important; border-top-width: 0 !important; }
#  #zmxduihwzs .gt_heading { background-color: #FFFFFF !important; text-align: center !important; border-bottom-color: #FFFFFF !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; }
#  #zmxduihwzs .gt_bottom_border { border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; }
#  #zmxduihwzs .gt_col_headings { border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; }
#  #zmxduihwzs .gt_col_heading { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: normal !important; text-transform: inherit !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: bottom !important; padding-top: 5px !important; padding-bottom: 5px !important; padding-left: 5px !important; padding-right: 5px !important; overflow-x: hidden !important; }
#  #zmxduihwzs .gt_column_spanner_outer { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: normal !important; text-transform: inherit !important; padding-top: 0 !important; padding-bottom: 0 !important; padding-left: 4px !important; padding-right: 4px !important; }
#  #zmxduihwzs .gt_column_spanner_outer:first-child { padding-left: 0 !important; }
#  #zmxduihwzs .gt_column_spanner_outer:last-child { padding-right: 0 !important; }
#  #zmxduihwzs .gt_column_spanner { border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; vertical-align: bottom !important; padding-top: 5px !important; padding-bottom: 5px !important; overflow-x: hidden !important; display: inline-block !important; width: 100% !important; }
#  #zmxduihwzs .gt_spanner_row { border-bottom-style: hidden !important; }
#  #zmxduihwzs .gt_group_heading { padding-top: 8px !important; padding-bottom: 8px !important; padding-left: 5px !important; padding-right: 5px !important; color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: middle !important; text-align: left !important; }
#  #zmxduihwzs .gt_empty_group_heading { padding: 0.5px !important; color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; vertical-align: middle !important; }
#  #zmxduihwzs .gt_from_md> :first-child { margin-top: 0 !important; }
#  #zmxduihwzs .gt_from_md> :last-child { margin-bottom: 0 !important; }
#  #zmxduihwzs .gt_row { padding-top: 8px !important; padding-bottom: 8px !important; padding-left: 5px !important; padding-right: 5px !important; margin: 10px !important; border-top-style: solid !important; border-top-width: 1px !important; border-top-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: middle !important; overflow-x: hidden !important; }
#  #zmxduihwzs .gt_stub { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-right-style: solid !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; padding-left: 5px !important; padding-right: 5px !important; }
#  #zmxduihwzs .gt_stub_row_group { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-right-style: solid !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; padding-left: 5px !important; padding-right: 5px !important; vertical-align: top !important; }
#  #zmxduihwzs .gt_row_group_first td { border-top-width: 2px !important; }
#  #zmxduihwzs .gt_row_group_first th { border-top-width: 2px !important; }
#  #zmxduihwzs .gt_striped { background-color: rgba(128,128,128,0.05) !important; }
#  #zmxduihwzs .gt_table_body { border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; }
#  #zmxduihwzs .gt_sourcenotes { color: #333333 !important; background-color: #F
# <div id="sjgmagcbfm" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #sjgmagcbfm table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #sjgmagcbfm thead, tbody, tfoot, tr, td, th { border-style: none !important; }
#  tr { background-color: transparent !important; }
# #sjgmagcbfm p { margin: 0 !important; padding: 0 !important; }
#  #sjgmagcbfm .gt_table { display: table !important; border-collapse: collapse !important; line-height: normal !important; margin-left: auto !important; margin-right: auto !important; color: #333333 !important; font-size: 16px !important; font-weight: normal !important; font-style: normal !important; background-color: #FFFFFF !important; width: auto !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #A8A8A8 !important; border-right-style: none !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #A8A8A8 !important; border-left-style: none !important; border-left-width: 2px !important; border-left-color: #D3D3D3 !important; }
#  #sjgmagcbfm .gt_caption { padding-top: 4px !important; padding-bottom: 4px !important; }
#  #sjgmagcbfm .gt_title { color: #333333 !important; font-size: 125% !important; font-weight: initial !important; padding-top: 4px !important; padding-bottom: 4px !important; padding-left: 5px !important; padding-right: 5px !important; border-bottom-color: #FFFFFF !important; border-bottom-width: 0 !important; }
#  #sjgmagcbfm .gt_subtitle { color: #333333 !important; font-size: 85% !important; font-weight: initial !important; padding-top: 3px !important; padding-bottom: 5px !important; padding-left: 5px !important; padding-right: 5px !important; border-top-color: #FFFFFF !important; border-top-width: 0 !important; }
#  #sjgmagcbfm .gt_heading { background-color: #FFFFFF !important; text-align: center !important; border-bottom-color: #FFFFFF !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; }
#  #sjgmagcbfm .gt_bottom_border { border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; }
#  #sjgmagcbfm .gt_col_headings { border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; }
#  #sjgmagcbfm .gt_col_heading { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: normal !important; text-transform: inherit !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: bottom !important; padding-top: 5px !important; padding-bottom: 5px !important; padding-left: 5px !important; padding-right: 5px !important; overflow-x: hidden !important; }
#  #sjgmagcbfm .gt_column_spanner_outer { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: normal !important; text-transform: inherit !important; padding-top: 0 !important; padding-bottom: 0 !important; padding-left: 4px !important; padding-right: 4px !important; }
#  #sjgmagcbfm .gt_column_spanner_outer:first-child { padding-left: 0 !important; }
#  #sjgmagcbfm .gt_column_spanner_outer:last-child { padding-right: 0 !important; }
#  #sjgmagcbfm .gt_column_spanner { border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; vertical-align: bottom !important; padding-top: 5px !important; padding-bottom: 5px !important; overflow-x: hidden !important; display: inline-block !important; width: 100% !important; }
#  #sjgmagcbfm .gt_spanner_row { border-bottom-style: hidden !important; }
#  #sjgmagcbfm .gt_group_heading { padding-top: 8px !important; padding-bottom: 8px !important; padding-left: 5px !important; padding-right: 5px !important; color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: middle !important; text-align: left !important; }
#  #sjgmagcbfm .gt_empty_group_heading { padding: 0.5px !important; color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; vertical-align: middle !important; }
#  #sjgmagcbfm .gt_from_md> :first-child { margin-top: 0 !important; }
#  #sjgmagcbfm .gt_from_md> :last-child { margin-bottom: 0 !important; }
#  #sjgmagcbfm .gt_row { padding-top: 8px !important; padding-bottom: 8px !important; padding-left: 5px !important; padding-right: 5px !important; margin: 10px !important; border-top-style: solid !important; border-top-width: 1px !important; border-top-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: middle !important; overflow-x: hidden !important; }
#  #sjgmagcbfm .gt_stub { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-right-style: solid !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; padding-left: 5px !important; padding-right: 5px !important; }
#  #sjgmagcbfm .gt_stub_row_group { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-right-style: solid !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; padding-left: 5px !important; padding-right: 5px !important; vertical-align: top !important; }
#  #sjgmagcbfm .gt_row_group_first td { border-top-width: 2px !important; }
#  #sjgmagcbfm .gt_row_group_first th { border-top-width: 2px !important; }
#  #sjgmagcbfm .gt_striped { background-color: rgba(128,128,128,0.05) !important; }
#  #sjgmagcbfm .gt_table_body { border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; }
#  #sjgmagcbfm .gt_sourcenotes { color: #333333 !important; background-color: #F
# <div id="soehffidnf" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #soehffidnf table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #soehffidnf thead, tbody, tfoot, tr, td, th { border-style: none !important; }
#  tr { background-color: transparent !important; }
# #soehffidnf p { margin: 0 !important; padding: 0 !important; }
#  #soehffidnf .gt_table { display: table !important; border-collapse: collapse !important; line-height: normal !important; margin-left: auto !important; margin-right: auto !important; color: #333333 !important; font-size: 16px !important; font-weight: normal !important; font-style: normal !important; background-color: #FFFFFF !important; width: auto !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #A8A8A8 !important; border-right-style: none !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #A8A8A8 !important; border-left-style: none !important; border-left-width: 2px !important; border-left-color: #D3D3D3 !important; }
#  #soehffidnf .gt_caption { padding-top: 4px !important; padding-bottom: 4px !important; }
#  #soehffidnf .gt_title { color: #333333 !important; font-size: 125% !important; font-weight: initial !important; padding-top: 4px !important; padding-bottom: 4px !important; padding-left: 5px !important; padding-right: 5px !important; border-bottom-color: #FFFFFF !important; border-bottom-width: 0 !important; }
#  #soehffidnf .gt_subtitle { color: #333333 !important; font-size: 85% !important; font-weight: initial !important; padding-top: 3px !important; padding-bottom: 5px !important; padding-left: 5px !important; padding-right: 5px !important; border-top-color: #FFFFFF !important; border-top-width: 0 !important; }
#  #soehffidnf .gt_heading { background-color: #FFFFFF !important; text-align: center !important; border-bottom-color: #FFFFFF !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; }
#  #soehffidnf .gt_bottom_border { border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; }
#  #soehffidnf .gt_col_headings { border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; }
#  #soehffidnf .gt_col_heading { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: normal !important; text-transform: inherit !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: bottom !important; padding-top: 5px !important; padding-bottom: 5px !important; padding-left: 5px !important; padding-right: 5px !important; overflow-x: hidden !important; }
#  #soehffidnf .gt_column_spanner_outer { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: normal !important; text-transform: inherit !important; padding-top: 0 !important; padding-bottom: 0 !important; padding-left: 4px !important; padding-right: 4px !important; }
#  #soehffidnf .gt_column_spanner_outer:first-child { padding-left: 0 !important; }
#  #soehffidnf .gt_column_spanner_outer:last-child { padding-right: 0 !important; }
#  #soehffidnf .gt_column_spanner { border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; vertical-align: bottom !important; padding-top: 5px !important; padding-bottom: 5px !important; overflow-x: hidden !important; display: inline-block !important; width: 100% !important; }
#  #soehffidnf .gt_spanner_row { border-bottom-style: hidden !important; }
#  #soehffidnf .gt_group_heading { padding-top: 8px !important; padding-bottom: 8px !important; padding-left: 5px !important; padding-right: 5px !important; color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: middle !important; text-align: left !important; }
#  #soehffidnf .gt_empty_group_heading { padding: 0.5px !important; color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; vertical-align: middle !important; }
#  #soehffidnf .gt_from_md> :first-child { margin-top: 0 !important; }
#  #soehffidnf .gt_from_md> :last-child { margin-bottom: 0 !important; }
#  #soehffidnf .gt_row { padding-top: 8px !important; padding-bottom: 8px !important; padding-left: 5px !important; padding-right: 5px !important; margin: 10px !important; border-top-style: solid !important; border-top-width: 1px !important; border-top-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: middle !important; overflow-x: hidden !important; }
#  #soehffidnf .gt_stub { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-right-style: solid !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; padding-left: 5px !important; padding-right: 5px !important; }
#  #soehffidnf .gt_stub_row_group { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-right-style: solid !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; padding-left: 5px !important; padding-right: 5px !important; vertical-align: top !important; }
#  #soehffidnf .gt_row_group_first td { border-top-width: 2px !important; }
#  #soehffidnf .gt_row_group_first th { border-top-width: 2px !important; }
#  #soehffidnf .gt_striped { background-color: rgba(128,128,128,0.05) !important; }
#  #soehffidnf .gt_table_body { border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; }
#  #soehffidnf .gt_sourcenotes { color: #333333 !important; background-color: #F
# <div id="grvsurqkru" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #grvsurqkru table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #grvsurqkru thead, tbody, tfoot, tr, td, th { border-style: none !important; }
#  tr { background-color: transparent !important; }
# #grvsurqkru p { margin: 0 !important; padding: 0 !important; }
#  #grvsurqkru .gt_table { display: table !important; border-collapse: collapse !important; line-height: normal !important; margin-left: auto !important; margin-right: auto !important; color: #333333 !important; font-size: 16px !important; font-weight: normal !important; font-style: normal !important; background-color: #FFFFFF !important; width: auto !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #A8A8A8 !important; border-right-style: none !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #A8A8A8 !important; border-left-style: none !important; border-left-width: 2px !important; border-left-color: #D3D3D3 !important; }
#  #grvsurqkru .gt_caption { padding-top: 4px !important; padding-bottom: 4px !important; }
#  #grvsurqkru .gt_title { color: #333333 !important; font-size: 125% !important; font-weight: initial !important; padding-top: 4px !important; padding-bottom: 4px !important; padding-left: 5px !important; padding-right: 5px !important; border-bottom-color: #FFFFFF !important; border-bottom-width: 0 !important; }
#  #grvsurqkru .gt_subtitle { color: #333333 !important; font-size: 85% !important; font-weight: initial !important; padding-top: 3px !important; padding-bottom: 5px !important; padding-left: 5px !important; padding-right: 5px !important; border-top-color: #FFFFFF !important; border-top-width: 0 !important; }
#  #grvsurqkru .gt_heading { background-color: #FFFFFF !important; text-align: center !important; border-bottom-color: #FFFFFF !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; }
#  #grvsurqkru .gt_bottom_border { border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; }
#  #grvsurqkru .gt_col_headings { border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; }
#  #grvsurqkru .gt_col_heading { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: normal !important; text-transform: inherit !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: bottom !important; padding-top: 5px !important; padding-bottom: 5px !important; padding-left: 5px !important; padding-right: 5px !important; overflow-x: hidden !important; }
#  #grvsurqkru .gt_column_spanner_outer { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: normal !important; text-transform: inherit !important; padding-top: 0 !important; padding-bottom: 0 !important; padding-left: 4px !important; padding-right: 4px !important; }
#  #grvsurqkru .gt_column_spanner_outer:first-child { padding-left: 0 !important; }
#  #grvsurqkru .gt_column_spanner_outer:last-child { padding-right: 0 !important; }
#  #grvsurqkru .gt_column_spanner { border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; vertical-align: bottom !important; padding-top: 5px !important; padding-bottom: 5px !important; overflow-x: hidden !important; display: inline-block !important; width: 100% !important; }
#  #grvsurqkru .gt_spanner_row { border-bottom-style: hidden !important; }
#  #grvsurqkru .gt_group_heading { padding-top: 8px !important; padding-bottom: 8px !important; padding-left: 5px !important; padding-right: 5px !important; color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: middle !important; text-align: left !important; }
#  #grvsurqkru .gt_empty_group_heading { padding: 0.5px !important; color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; vertical-align: middle !important; }
#  #grvsurqkru .gt_from_md> :first-child { margin-top: 0 !important; }
#  #grvsurqkru .gt_from_md> :last-child { margin-bottom: 0 !important; }
#  #grvsurqkru .gt_row { padding-top: 8px !important; padding-bottom: 8px !important; padding-left: 5px !important; padding-right: 5px !important; margin: 10px !important; border-top-style: solid !important; border-top-width: 1px !important; border-top-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: middle !important; overflow-x: hidden !important; }
#  #grvsurqkru .gt_stub { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-right-style: solid !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; padding-left: 5px !important; padding-right: 5px !important; }
#  #grvsurqkru .gt_stub_row_group { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-right-style: solid !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; padding-left: 5px !important; padding-right: 5px !important; vertical-align: top !important; }
#  #grvsurqkru .gt_row_group_first td { border-top-width: 2px !important; }
#  #grvsurqkru .gt_row_group_first th { border-top-width: 2px !important; }
#  #grvsurqkru .gt_striped { background-color: rgba(128,128,128,0.05) !important; }
#  #grvsurqkru .gt_table_body { border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; }
#  #grvsurqkru .gt_sourcenotes { color: #333333 !important; background-color: #F

# %%
# Render nicely in Jupyter or compatible environments
fusion_table.show()
# Out:
# <div id="vjvsvbaomh" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #vjvsvbaomh table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #vjvsvbaomh thead, tbody, tfoot, tr, td, th { border-style: none !important; }
#  tr { background-color: transparent !important; }
# #vjvsvbaomh p { margin: 0 !important; padding: 0 !important; }
#  #vjvsvbaomh .gt_table { display: table !important; border-collapse: collapse !important; line-height: normal !important; margin-left: auto !important; margin-right: auto !important; color: #333333 !important; font-size: 16px !important; font-weight: normal !important; font-style: normal !important; background-color: #FFFFFF !important; width: auto !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #A8A8A8 !important; border-right-style: none !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #A8A8A8 !important; border-left-style: none !important; border-left-width: 2px !important; border-left-color: #D3D3D3 !important; }
#  #vjvsvbaomh .gt_caption { padding-top: 4px !important; padding-bottom: 4px !important; }
#  #vjvsvbaomh .gt_title { color: #333333 !important; font-size: 125% !important; font-weight: initial !important; padding-top: 4px !important; padding-bottom: 4px !important; padding-left: 5px !important; padding-right: 5px !important; border-bottom-color: #FFFFFF !important; border-bottom-width: 0 !important; }
#  #vjvsvbaomh .gt_subtitle { color: #333333 !important; font-size: 85% !important; font-weight: initial !important; padding-top: 3px !important; padding-bottom: 5px !important; padding-left: 5px !important; padding-right: 5px !important; border-top-color: #FFFFFF !important; border-top-width: 0 !important; }
#  #vjvsvbaomh .gt_heading { background-color: #FFFFFF !important; text-align: center !important; border-bottom-color: #FFFFFF !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; }
#  #vjvsvbaomh .gt_bottom_border { border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; }
#  #vjvsvbaomh .gt_col_headings { border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; }
#  #vjvsvbaomh .gt_col_heading { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: normal !important; text-transform: inherit !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: bottom !important; padding-top: 5px !important; padding-bottom: 5px !important; padding-left: 5px !important; padding-right: 5px !important; overflow-x: hidden !important; }
#  #vjvsvbaomh .gt_column_spanner_outer { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: normal !important; text-transform: inherit !important; padding-top: 0 !important; padding-bottom: 0 !important; padding-left: 4px !important; padding-right: 4px !important; }
#  #vjvsvbaomh .gt_column_spanner_outer:first-child { padding-left: 0 !important; }
#  #vjvsvbaomh .gt_column_spanner_outer:last-child { padding-right: 0 !important; }
#  #vjvsvbaomh .gt_column_spanner { border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; vertical-align: bottom !important; padding-top: 5px !important; padding-bottom: 5px !important; overflow-x: hidden !important; display: inline-block !important; width: 100% !important; }
#  #vjvsvbaomh .gt_spanner_row { border-bottom-style: hidden !important; }
#  #vjvsvbaomh .gt_group_heading { padding-top: 8px !important; padding-bottom: 8px !important; padding-left: 5px !important; padding-right: 5px !important; color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: middle !important; text-align: left !important; }
#  #vjvsvbaomh .gt_empty_group_heading { padding: 0.5px !important; color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; vertical-align: middle !important; }
#  #vjvsvbaomh .gt_from_md> :first-child { margin-top: 0 !important; }
#  #vjvsvbaomh .gt_from_md> :last-child { margin-bottom: 0 !important; }
#  #vjvsvbaomh .gt_row { padding-top: 8px !important; padding-bottom: 8px !important; padding-left: 5px !important; padding-right: 5px !important; margin: 10px !important; border-top-style: solid !important; border-top-width: 1px !important; border-top-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: middle !important; overflow-x: hidden !important; }
#  #vjvsvbaomh .gt_stub { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-right-style: solid !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; padding-left: 5px !important; padding-right: 5px !important; }
#  #vjvsvbaomh .gt_stub_row_group { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-right-style: solid !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; padding-left: 5px !important; padding-right: 5px !important; vertical-align: top !important; }
#  #vjvsvbaomh .gt_row_group_first td { border-top-width: 2px !important; }
#  #vjvsvbaomh .gt_row_group_first th { border-top-width: 2px !important; }
#  #vjvsvbaomh .gt_striped { background-color: rgba(128,128,128,0.05) !important; }
#  #vjvsvbaomh .gt_table_body { border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; }
#  #vjvsvbaomh .gt_sourcenotes { color: #333333 !important; background-color: #F

# %%
from IPython.display import display, HTML
display(HTML(fusion_table._repr_html_()))
# Out:
# <div id="uukqzxrpxw" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
# <style>
# #uukqzxrpxw table {
#           font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
#           -webkit-font-smoothing: antialiased;
#           -moz-osx-font-smoothing: grayscale;
#         }
#
# #uukqzxrpxw thead, tbody, tfoot, tr, td, th { border-style: none !important; }
#  tr { background-color: transparent !important; }
# #uukqzxrpxw p { margin: 0 !important; padding: 0 !important; }
#  #uukqzxrpxw .gt_table { display: table !important; border-collapse: collapse !important; line-height: normal !important; margin-left: auto !important; margin-right: auto !important; color: #333333 !important; font-size: 16px !important; font-weight: normal !important; font-style: normal !important; background-color: #FFFFFF !important; width: auto !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #A8A8A8 !important; border-right-style: none !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #A8A8A8 !important; border-left-style: none !important; border-left-width: 2px !important; border-left-color: #D3D3D3 !important; }
#  #uukqzxrpxw .gt_caption { padding-top: 4px !important; padding-bottom: 4px !important; }
#  #uukqzxrpxw .gt_title { color: #333333 !important; font-size: 125% !important; font-weight: initial !important; padding-top: 4px !important; padding-bottom: 4px !important; padding-left: 5px !important; padding-right: 5px !important; border-bottom-color: #FFFFFF !important; border-bottom-width: 0 !important; }
#  #uukqzxrpxw .gt_subtitle { color: #333333 !important; font-size: 85% !important; font-weight: initial !important; padding-top: 3px !important; padding-bottom: 5px !important; padding-left: 5px !important; padding-right: 5px !important; border-top-color: #FFFFFF !important; border-top-width: 0 !important; }
#  #uukqzxrpxw .gt_heading { background-color: #FFFFFF !important; text-align: center !important; border-bottom-color: #FFFFFF !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; }
#  #uukqzxrpxw .gt_bottom_border { border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; }
#  #uukqzxrpxw .gt_col_headings { border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; }
#  #uukqzxrpxw .gt_col_heading { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: normal !important; text-transform: inherit !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: bottom !important; padding-top: 5px !important; padding-bottom: 5px !important; padding-left: 5px !important; padding-right: 5px !important; overflow-x: hidden !important; }
#  #uukqzxrpxw .gt_column_spanner_outer { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: normal !important; text-transform: inherit !important; padding-top: 0 !important; padding-bottom: 0 !important; padding-left: 4px !important; padding-right: 4px !important; }
#  #uukqzxrpxw .gt_column_spanner_outer:first-child { padding-left: 0 !important; }
#  #uukqzxrpxw .gt_column_spanner_outer:last-child { padding-right: 0 !important; }
#  #uukqzxrpxw .gt_column_spanner { border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; vertical-align: bottom !important; padding-top: 5px !important; padding-bottom: 5px !important; overflow-x: hidden !important; display: inline-block !important; width: 100% !important; }
#  #uukqzxrpxw .gt_spanner_row { border-bottom-style: hidden !important; }
#  #uukqzxrpxw .gt_group_heading { padding-top: 8px !important; padding-bottom: 8px !important; padding-left: 5px !important; padding-right: 5px !important; color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: middle !important; text-align: left !important; }
#  #uukqzxrpxw .gt_empty_group_heading { padding: 0.5px !important; color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; vertical-align: middle !important; }
#  #uukqzxrpxw .gt_from_md> :first-child { margin-top: 0 !important; }
#  #uukqzxrpxw .gt_from_md> :last-child { margin-bottom: 0 !important; }
#  #uukqzxrpxw .gt_row { padding-top: 8px !important; padding-bottom: 8px !important; padding-left: 5px !important; padding-right: 5px !important; margin: 10px !important; border-top-style: solid !important; border-top-width: 1px !important; border-top-color: #D3D3D3 !important; border-left-style: none !important; border-left-width: 1px !important; border-left-color: #D3D3D3 !important; border-right-style: none !important; border-right-width: 1px !important; border-right-color: #D3D3D3 !important; vertical-align: middle !important; overflow-x: hidden !important; }
#  #uukqzxrpxw .gt_stub { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-right-style: solid !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; padding-left: 5px !important; padding-right: 5px !important; }
#  #uukqzxrpxw .gt_stub_row_group { color: #333333 !important; background-color: #FFFFFF !important; font-size: 100% !important; font-weight: initial !important; text-transform: inherit !important; border-right-style: solid !important; border-right-width: 2px !important; border-right-color: #D3D3D3 !important; padding-left: 5px !important; padding-right: 5px !important; vertical-align: top !important; }
#  #uukqzxrpxw .gt_row_group_first td { border-top-width: 2px !important; }
#  #uukqzxrpxw .gt_row_group_first th { border-top-width: 2px !important; }
#  #uukqzxrpxw .gt_striped { background-color: rgba(128,128,128,0.05) !important; }
#  #uukqzxrpxw .gt_table_body { border-top-style: solid !important; border-top-width: 2px !important; border-top-color: #D3D3D3 !important; border-bottom-style: solid !important; border-bottom-width: 2px !important; border-bottom-color: #D3D3D3 !important; }
#  #uukqzxrpxw .gt_sourcenotes { color: #333333 !important; background-color: #F

# %%
# Step 1: Initialize the table generator
table_generator = MultimodalTableGenerator()

# Step 2: Generate the benchmark data
benchmark_data = table_generator.generate_comprehensive_benchmark_data()

# Step 3: Access individual tables (optional)
model_comparison_df = benchmark_data['model_comparison']
modality_performance_df = benchmark_data['modality_performance']
audio_metrics_df = benchmark_data['audio_metrics']
video_metrics_df = benchmark_data['video_metrics']
benchmark_scores_df = benchmark_data['benchmark_scores']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 13
#      11 video_metrics_df = benchmark_data['video_metrics']
#      12 benchmark_scores_df = benchmark_data['benchmark_scores']
# ---> 13 create_model_comparison_table(model_comparison_df)
#
# TypeError: create_model_comparison_table() missing 1 required positional argument: 'df'
